# %%
'''Problem 1: Unique Words in a Sentence
Problem Statement
Given a sentence, identify all unique words and display:
The count of unique words
The unique words themselves

Input
Enter sentence: python is easy and python is powerful

Expected Output
Unique words count: 5  
Unique words: {'python', 'is', 'easy', 'and', 'powerful'}
'''
sentence="python is easy and python is powerful"
#Split the sentence into individual words.
sentence=sentence.split()
#Convert the list of words into a set to remove duplicates.
sentence=set(dict.fromkeys(sentence))
#Print both the set and its length
count=0
for word in sentence:
    count+=1
print("Unique words count:",count)
print("Unique words:",sentence)
# Out:
# Unique words count: 5
# Unique words: {'and', 'python', 'easy', 'is', 'powerful'}

# %%
'''Problem 2: Highest Salary from Employee Data
Problem Statement
Store employee names and their salaries, and determine which employee has the highest salary.
Hint
Use a dictionary where the key is the employee name and the value is the salary.
Compare salary values to find the highest.
Input Format
A dictionary where:
Keys represent employee names
Values represent employee salaries
Example Input
employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000
}

Expected Output
Highest Salary: Ravi - 75000
'''
employees={
    "Ravi":75000,
    "Anita":68000,
    "Kiran":72000
}
print("Highest Salary:",max(employees.keys()),"-",max(employees.values()))
# Out:
# Highest Salary: Ravi - 75000

# %%
'''Problem 3: Find Maximum and Minimum Values
Problem Statement
Find the maximum and minimum values from a list of numbers.
Hint
Initialize both maximum and minimum with the first element of the list.
Use a loop to compare each element.
Input Format
A list of integers where each element represents a numeric value.
Example Input
numbers = [45, 22, 89, 10, 66]

Expected Output
List: [45, 22, 89, 10, 66]  
Max: 89  
Min: 10
'''
numbers = [45, 22, 89, 10, 66]
Max=numbers[0]
Min=numbers[0]
for num in numbers:
    if num>Max:
        Max=num
    elif num<Min:
        Min=num
print(numbers)
print("Max:",Max)
print("Min:",Min)
# Out:
# [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %%
'''Problem 4: Count Products Above a Price Threshold
Problem Statement
Count how many products have a price greater than 1000.
Hint
Use a loop to compare each price with 1000.
Input Format
A list of integers where each element represents the price of a product.
Example Input
prices = [450, 1200, 899, 1500, 300]

Expected Output
Products above 1000: 2
'''
prices = [450, 1200, 899, 1500, 300]
product=0
for price in prices:
    if price>1000:
        product+=1
print("Products above 1000:",product)
# Out:
# Products above 1000: 2

# %%
'''Problem 5: Calculate Attendance Percentage
Problem Statement
Calculate the attendance percentage from a list containing "P" (Present) and "A" (Absent).
Hint
Count the number of "P" values.
Divide by the total number of days.
Example Input
attendance = ["P", "P", "A", "P", "P"]

Expected Output
Attendance Percentage: 80.0
'''
attendance = ["P", "P", "A", "P", "P"]
present=0
numberOfDays=0
for attend in attendance:
    numberOfDays+=1
    if attend=="P":
        present+=1
percentage=(present/numberOfDays)*100
print("Attendance Percentage:",percentage)
# Out:
# Attendance Percentage: 80.0

# %%
'''Problem 6: Remove Duplicate Phone Numbers
Problem Statement
You are given a list of phone numbers that may contain duplicates. Write a Python program to remove duplicate phone numbers and
display only the unique phone numbers.
Hint
Convert the list into a set.
Sets automatically remove duplicate values.
Input Format
A list of integers where each integer represents a phone number.
Example Input
phone_numbers = [9876543210, 9123456789, 9876543210]

Expected Output
Unique phone numbers: {9876543210, 9123456789}
'''
phone_numbers = [9876543210, 9123456789, 9876543210]
unique_phone_nums=set(phone_numbers)
print("Unique phone numbers:",unique_phone_nums)
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %%
'''Problem 7: Count Character Frequency
Problem Statement
Count how many times each character appears in a given string.
Hint
Use a dictionary.
Increment the count for each character occurrence.
Expected Output
{'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}
'''
str=input("Enter a string")
dict={}
for char in str:
    key=dict.keys()
    if char in key:
        dict[char]+=1
    else:
        dict[char]=1
print(dict)
# Out:
# Enter a string python programming
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 2, 'n': 2, ' ': 1, 'r': 2, 'g': 2, 'a': 1, 'm': 2, 'i': 1}

# %%
'''Problem 8: Convert List to Tuple
Problem Statement
Convert a list into a tuple and display it.
Hint
Use the tuple() function.
Expected Output
Tuple: (10, 20, 30)
'''
list_items=[10,20,30,40,50,60,70]
print(tuple(list_items))
# Out:
# (10, 20, 30, 40, 50, 60, 70)

# %%
'''Problem 9: Check if a Key Exists in a Dictionary
Problem Statement
Check whether a specific key exists in a dictionary.
Hint
Use the in keyword.
Expected Output
Employee exists
'''
employees={
    "emp_id":101,
    "emp_name":"Sachin",
    "salary":10000
}
key=input("Enter a key")
if key in employees:
    print(key," exists")
else:
    print(key," not exists")
# Out:
# Enter a key emo
# emo  not exists

# %%
'''Problem 10: Calculate Average Marks
Problem Statement
Calculate the average marks of a student from a list of marks.
Hint
Calculate the sum of all values.
Divide by the total number of marks.
Expected Output
Average Marks: 72.5
'''
marks_list=[39,70,94,38,58,66]
sum=0
marks_count=0
for marks in marks_list:
    marks_count+=1
    sum+=marks
marks_count=marks_count
percentage=(sum/marks_count)
print(percentage)
# Out:
# 60.833333333333336
